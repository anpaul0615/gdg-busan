# %% [markdown]
# # (번외) 디지털 그래픽

# %% [markdown]
# - 디지털 이미지 개념..?
#   0101 로 표현된..? 픽셀 하나하나로 나뉘어져서 rgb등으로 표현된..~
#
# - image 라는 용어..?
#   영상이랑 사진은 본진적으로 동일함
#   이미지 란, 물체에 대한 "상" 자체를 가리키는 말임 (정적인이미지,동적인이미지)
#   용어정의 주의~!
#
# - 디지털이미지는 이차원 행렬로 표현~
#   위치로 xy 표현되는 행렬~
#   하나의 점이 아니라 픽셀 이라는것에 유의함!
#
# - 그레이스케일 이미지..?
#   8비트로 명암을 표현하는~
#
# - 컬러이미지..?
#   8 * 3 = 24비트로 표현 (즉 2^24승 가지의 색을 표현가능함)
#   rgb 를 표현
#
# - rgb 는 정육면체로 구성된 행렬로 구성된~
#   빛의삼원색으로 표현
#
# - hsv(hue sparated v) 컬러 스페이스..?
#   명도 채도 밝기 로 표현..?
#
# - cmyk..?
#   색의 삼원색으로 표현..!
#   출력할때는 cmyk 를 사용해야 본대로 나옴!
#
# - 벡터데이터..?
#   확대해도 안깨지는~~
#   svg같은 포멧~~
#
# - bitmap, jpec, png

# %% [markdown]
# - 히스토그램..?
#   이미지 한장에 들어있는 픽셀들의 색상범주집계값..?
#   어떤색상이 얼마나있는지 알수있는~
#   그레이스케일은 차트1개
#   rgb 는 차트3개
#
# - 노출..?
#
# - 콘트라스트..?
#   히스토그램의 범위가 좁을수록 이미지의 픽셀들의 차이가 비슷하다는..
#   범위가 넓을수록 색의 구분이 분명하다는 의미임..!
#
# - 다이나믹레인지..?
#   컬러가 연속적이지 않은 차트..?
#   이미지가 깨져서 보임~
#
# - 히스토그램 총합..?
#   색의 분포도를 기울기로 완만하게 표현하는 목적으로..?
#
# - 채도..? (==색의 강도)
#   색의 순수한 정도..?
#   주위의 색을 고려하지 않고 자기자신에대한 색의 표현력..? 값..?
#   rgb 값에 채도를 곱한다..?? => 0에 가까워질수록 그레이스케일로~!!
#
# - 대비..?
#   컬러의 픽셀들의 범주집계 범위
#   주위의 색을 고려해서 유사한가? 구분되는가? 를 정돌를 포현
#
# - 색을 일정 수식을 기반으로 통합/구분 해서 최대한 단순화해서 컴퓨터비전으로 인식하기위한 전처리에서 사용~
#
# - 오토 콘트라스트..?
#   색의 픽셀 범주를 min/max 양끝 값들을 날려버리고 중앙에 최대한 평균값으로 콘트라스트를 조정하는~
#   이미지크기에 비례해서~

# %% [markdown]
# - 필터..? 마스크..?
#
# - 픽셀을 한칸씩 나눠서 n * n 범위로 순회하면서 필터 적용하는~?
#   필터범위의 각 필셀값들에 대한 평균으로 해당 단일픽셀의 값을 업데이트~
#   필터범위 최외곽에 패딩값0으로채움~ 보통~
#
# - 필터복구..?
#   이미지프로세싱할때는 원본을 카피해서 써라~
#   (필터는 일반적으로 복구가안되기때문~)
#
# - border 처리방법..?
#   필터 최외곽쪽에는 일반적으로 필터범위 적용이 안되기때문에~
#   한색으로채우거나~ 블러처리를하거나~ 등등 (패딩을채우거나~)
#
# - 리니어필터 종류..?
#   블러(민필터)~
#   가우시안~ 중앙을 강조하는~ 수채화느낌?
#   나플라스~ 테두리를버리는~
#
# - 미디움필터..?
#   노이즈제거용으로 사용~
#   극단적인 값에 대해서 9개의 값을 중간값으로 설정하는~~
#   국소부위에 사용하면 좋은데, 전체에 다 사용하면 경계가 흐릿해지는... (cv 에 부적합)
